# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.scatter(data.area,data.price,color="red",marker="*")
plt.plot(data.area,reg.predict(data[["area"]]))
plt.xlabel("area")
plt.ylabel("price")
plt.title("area vs price")
plt.show()

# %%
plt.plot(data["area"],data["price"])

# %%
import numpy as np
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()
reg.fit(data[["area"]],data.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.predict([[3300]])
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.predict([[5000]])
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
data1=pd.read_csv("C:\\Users\\raghu\\Downloads\\areas.csv")
data1
# Out:
#    areas
# 0   1000
# 1   1200
# 2   1300
# 3   1400
# 4   1500
# 5   1600
# 6   2700
# 7   2800
# 8   2900
# 9   3100

# %%
reg.predict(data1)
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - areas
# Feature names seen at fit time, yet now missing:
# - area
#
#   warnings.warn(message, FutureWarning)
# array([316404.10958904, 343561.64383562, 357140.4109589 , 370719.17808219,
#        384297.94520548, 397876.71232877, 547243.15068493, 560821.91780822,
#        574400.68493151, 601558.21917808])

# %%
prices=reg.predict(data1)
# Out:
# C:\Users\raghu\anaconda3\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - areas
# Feature names seen at fit time, yet now missing:
# - area
#
#   warnings.warn(message, FutureWarning)

# %%
prices
# Out:
# array([316404.10958904, 343561.64383562, 357140.4109589 , 370719.17808219,
#        384297.94520548, 397876.71232877, 547243.15068493, 560821.91780822,
#        574400.68493151, 601558.21917808])

# %%
data1["prices"]=prices

# %%
data1
# Out:
#    areas         prices
# 0   1000  316404.109589
# 1   1200  343561.643836
# 2   1300  357140.410959
# 3   1400  370719.178082
# 4   1500  384297.945205
# 5   1600  397876.712329
# 6   2700  547243.150685
# 7   2800  560821.917808
# 8   2900  574400.684932
# 9   3100  601558.219178

# %%
data=pd.read_csv("C:\\Users\\raghu\\Downloads\\canada.csv")
data
# Out:
#     year  per capita income (US$)    Unnamed: 2
# 0    NaN                     1970   3399.299037
# 1    NaN                     1971   3768.297935
# 2    NaN                     1972   4251.175484
# 3    NaN                     1973   4804.463248
# 4    NaN                     1974   5576.514583
# 5    NaN                     1975   5998.144346
# 6    NaN                     1976   7062.131392
# 7    NaN                     1977   7100.126170
# 8    NaN                     1978   7247.967035
# 9    NaN                     1979   7602.912681
# 10   NaN                     1980   8355.968120
# 11   NaN                     1981   9434.390652
# 12   NaN                     1982   9619.438377
# 13   NaN                     1983  10416.536590
# 14   NaN                     1984  10790.328720
# 15   NaN                     1985  11018.955850
# 16   NaN                     1986  11482.891530
# 17   NaN                     1987  12974.806620
# 18   NaN                     1988  15080.283450
# 19   NaN                     1989  16426.725480
# 20   NaN                     1990  16838.673200
# 21   NaN                     1991  17266.097690
# 22   NaN                     1992  16412.083090
# 23   NaN                     1993  15875.586730
# 24   NaN                     1994  15755.820270
# 25   NaN                     1995  16369.317250
# 26   NaN                     1996  16699.826680
# 27   NaN                     1997  17310.757750
# 28   NaN                     1998  16622.671870
# 29   NaN                     1999  17581.024140
# 30   NaN                     2000  18987.382410
# 31   NaN                     2001  18601.397240
# 32   NaN                     2002  19232.175560
# 33   NaN                     2003  22739.426280
# 34   NaN                     2004  25719.147150
# 35   NaN                     2005  29198.055690
# 36   NaN                     2006  32738.262900
# 37   NaN                     2007  36144.481220
# 38   NaN                     2008  37446.486090
# 39   NaN                     2009  32755.176820
# 40   NaN                     2010  38420.522890
# 41   NaN                     2011  42334.711210
# 42   NaN                     2012  42665.255970
# 43   NaN                     2013  42676.468370
# 44   NaN                     2014  41039.893600
# 45   NaN                     2015  35175.188980
# 46   NaN                     2016  34229.193630
